# %% [markdown]
# ## Contact List Manager
#
# We wish to create a menu-driven program to manage a contact list. First, let us create all the functions we would need to compile this program. Every function will be applied to the contacts dictionary.
#
# Create an empty dictionary to test all the functions on it.
#
# (24 marks. 6 marks each.)

# %% [markdown]
# Function1: Add a Contact
#   - Function: add_contact(name, phone, contacts)
#   - This function should add a contact with the given name (string) and phone number (string) to contacts (a dictionary).
#   - It should also print out the added contact: <br>
#    "Contact Added. Ahmad - 0985435678"

# %% [markdown]
# Function2: Search a Contact
#   - Function: search_contact(name, contacts)
#   - This function should search for a contact by name in the contacts dictionary. If found, print the phone number: <br>
#   "Ahmad's phone number is 0985435678"
#   - otherwise, return a message: <br>
#   "This contact does not exist."

# %% [markdown]
# Function3: Delete a Contact
#   - Function: delete_contact(name, contacts)
#   - This function should remove the contact with the given name from the contacts dictionary. It should also print a message: <br>
#   "Contact deleted: Ahmad"
#   - If the name is not found, display "name not found"

# %% [markdown]
# Function4: Display All Contacts
#   - Function: display_contacts(contacts)
#   - This function should display all the contacts in the contact list:
#
# Contact List: <br>
# Ahmad: 0985435678 <br>
# Maimoona: 0123456789
#
#
#  - If no contacts are available, display a message indicating that the contact list is empty.

# %% [markdown]
# Compile all the functions above into a program.
# Guidelines:
#   - Create an empty dictionary called contacts.
#   - Implement a while loop to repeatedly display a menu and ask the user to choose an option. the loop should keep running until the user chooses the exit option.
#   - Use conditional statements to handle each menu option.
#   - Depending on which option the user chose, take appropriate input from the user for that option. for example, if they chose the add contact option, then prompt them to input a name and a phone number and call on the appropriate function to add that name and phone number to contacts.
#
# (16 marks)

# %% [markdown]
# ### Output of Contact List Manager Program:
#
# ```
#
# Contact Manager:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice: 1
#
# Enter name: Maimoona
# Enter phone number: 0123456789
# Contact added: Maimoona - 0123456789
#
# Contact Manager:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice: 1
#
# Enter name: Ahmad
# Enter phone number: 0985435678
# Contact added: Ahmad - 0985435678
#
# Contact Manager:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice: 4
#
# Contact List:
# Maimoona: 0123456789
# Ahmad: 0985435678
#
# Contact Manager:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice: 2
#
# Enter name to search: Ahmad
# Ahmad's phone number is 0985435678
#
# Contact Manager:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice: 3
#
# Enter name to delete: Ahmad
# Contact deleted: Ahmad
#
# Contact Manager:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice: 3
#
# Enter name to delete: Maimoona
# Contact deleted: Maimoona
#
# Contact Manager:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice: 4
#
# No contacts available.
#
# Contact Manager:
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice: 5
#
# Exiting Contact Manager. Goodbye!```

# %% [markdown]
# # Good Luck!
